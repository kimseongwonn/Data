# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# 데이터 불러오기

# %%
path = '/content/drive/MyDrive/mulcam_bigdata/2024통계데이터공모전/기획_데이터수집/성원님/Data/지역내총생산'

# %%
서울 = pd.read_csv(path + '/서울.csv')
부산 = pd.read_csv(path + '/부산.csv')
대구 = pd.read_csv(path + '/대구.csv')
인천 = pd.read_csv(path + '/인천.csv')
광주 = pd.read_csv(path + '/광주.csv')
대전 = pd.read_csv(path + '/대전.csv')
울산 = pd.read_csv(path + '/울산.csv')
경기 = pd.read_csv(path + '/경기.csv')
강원 = pd.read_csv(path + '/강원.csv')
충북 = pd.read_csv(path + '/충북.csv')
충남 = pd.read_csv(path + '/충남.csv')
전북 = pd.read_csv(path + '/전북.csv')
전남 = pd.read_csv(path + '/전남.csv')
경북 = pd.read_csv(path + '/경북.csv')
경남 = pd.read_csv(path + '/경남.csv')
제주 = pd.read_csv(path + '/제주.csv')

# %% [markdown]
# 데이터 확인

# %%
서울.head()
# Out:
#    자치구별(1)  자치구별(2)      경제활동별(1)      2021
# 0  자치구별(1)  자치구별(2)      경제활동별(1)     당해년가격
# 1      서울시      종로구  지역내총생산(시장가격)  35719537
# 2      서울시       중구  지역내총생산(시장가격)  61342710
# 3      서울시      용산구  지역내총생산(시장가격)  13294640
# 4      서울시      성동구  지역내총생산(시장가격)  13999893

# %%
서울.drop(0,axis=0, inplace=True)

# %%
서울.drop('자치구별(1)', axis=1, inplace=True)

# %%
서울.columns = ['행정구역시군구명', '내용', '금액']

# %%
서울['행정구역시도명'] = '서울특별시'

# %%
서울
# Out:
#    행정구역시군구명            내용        금액 행정구역시도명
# 1       종로구  지역내총생산(시장가격)  35719537   서울특별시
# 2        중구  지역내총생산(시장가격)  61342710   서울특별시
# 3       용산구  지역내총생산(시장가격)  13294640   서울특별시
# 4       성동구  지역내총생산(시장가격)  13999893   서울특별시
# 5       광진구  지역내총생산(시장가격)   6554954   서울특별시
# 6      동대문구  지역내총생산(시장가격)   7711273   서울특별시
# 7       중랑구  지역내총생산(시장가격)   4860242   서울특별시
# 8       성북구  지역내총생산(시장가격)   6371894   서울특별시
# 9       강북구  지역내총생산(시장가격)   3462961   서울특별시
# 10      도봉구  지역내총생산(시장가격)   3490683   서울특별시
# 11      노원구  지역내총생산(시장가격)   6728358   서울특별시
# 12      은평구  지역내총생산(시장가격)   5112192   서울특별시
# 13     서대문구  지역내총생산(시장가격)   9039083   서울특별시
# 14      마포구  지역내총생산(시장가격)  21399314   서울특별시
# 15      양천구  지역내총생산(시장가격)   7356067   서울특별시
# 16      강서구  지역내총생산(시장가격)  18347568   서울특별시
# 17      구로구  지역내총생산(시장가격)  14663398   서울특별시
# 18      금천구  지역내총생산(시장가격)  17801015   서울특별시
# 19     영등포구  지역내총생산(시장가격)  44265877   서울특별시
# 20      동작구  지역내총생산(시장가격)   6712864   서울특별시
# ...

# %%
부산.head()
# Out:
#    시군구별(1)      경제활동별(1)     2021
# 0  시군구별(1)      경제활동별(1)    당해년가격
# 1       중구  지역내총생산(시장가격)  3589526
# 2       서구  지역내총생산(시장가격)  3476168
# 3       동구  지역내총생산(시장가격)  4360438
# 4      영도구  지역내총생산(시장가격)  2697147

# %%
부산.drop(0,axis=0, inplace=True)

# %%
부산.columns = ['행정구역시군구명', '내용', '금액']

# %%
부산['행정구역시도명'] = '부산광역시'

# %%
부산
# Out:
#    행정구역시군구명            내용        금액 행정구역시도명
# 1        중구  지역내총생산(시장가격)   3589526   부산광역시
# 2        서구  지역내총생산(시장가격)   3476168   부산광역시
# 3        동구  지역내총생산(시장가격)   4360438   부산광역시
# 4       영도구  지역내총생산(시장가격)   2697147   부산광역시
# 5      부산진구  지역내총생산(시장가격)   9061721   부산광역시
# 6       동래구  지역내총생산(시장가격)   4319168   부산광역시
# 7        남구  지역내총생산(시장가격)   7907772   부산광역시
# 8        북구  지역내총생산(시장가격)   3322130   부산광역시
# 9      해운대구  지역내총생산(시장가격)   9174796   부산광역시
# 10      사하구  지역내총생산(시장가격)   7139515   부산광역시
# 11      금정구  지역내총생산(시장가격)   4656596   부산광역시
# 12      강서구  지역내총생산(시장가격)  15703315   부산광역시
# 13      연제구  지역내총생산(시장가격)   6408434   부산광역시
# 14      수영구  지역내총생산(시장가격)   2957435   부산광역시
# 15      사상구  지역내총생산(시장가격)   6444209   부산광역시
# 16      기장군  지역내총생산(시장가격)   6587541   부산광역시

# %%
대구.head()
# Out:
#    시군구별(1)      경제활동별(1)     2021
# 0  시군구별(1)      경제활동별(1)       명목
# 1       중구  지역내총생산(시장가격)  6108382
# 2       동구  지역내총생산(시장가격)  7974339
# 3       서구  지역내총생산(시장가격)  4188656
# 4       남구  지역내총생산(시장가격)  2927437

# %%
대구.drop(0,axis=0, inplace=True)
대구.columns = ['행정구역시군구명', '내용', '금액']
대구['행정구역시도명'] = '대구광역시'
대구
# Out:
#   행정구역시군구명            내용        금액 행정구역시도명
# 1       중구  지역내총생산(시장가격)   6108382   대구광역시
# 2       동구  지역내총생산(시장가격)   7974339   대구광역시
# 3       서구  지역내총생산(시장가격)   4188656   대구광역시
# 4       남구  지역내총생산(시장가격)   2927437   대구광역시
# 5       북구  지역내총생산(시장가격)   9542554   대구광역시
# 6      수성구  지역내총생산(시장가격)   8919264   대구광역시
# 7      달서구  지역내총생산(시장가격)  12790786   대구광역시
# 8      달성군  지역내총생산(시장가격)   8535736   대구광역시

# %%
인천.head()
# Out:
#    시군구별         경제활동별       2021
# 0  시군구별         경제활동별  당해년가격(명목)
# 1   강화군  지역내총생산(시장가격)    1770132
# 2   옹진군  지역내총생산(시장가격)     933335
# 3    중구  지역내총생산(시장가격)   14922471
# 4    동구  지역내총생산(시장가격)    4375516

# %%
인천.drop(0,axis=0, inplace=True)
인천.columns = ['행정구역시군구명', '내용', '금액']
인천['행정구역시도명'] = '인천광역시'
인천
# Out:
#    행정구역시군구명            내용        금액 행정구역시도명
# 1       강화군  지역내총생산(시장가격)   1770132   인천광역시
# 2       옹진군  지역내총생산(시장가격)    933335   인천광역시
# 3        중구  지역내총생산(시장가격)  14922471   인천광역시
# 4        동구  지역내총생산(시장가격)   4375516   인천광역시
# 5      미추홀구  지역내총생산(시장가격)   8092829   인천광역시
# 6       연수구  지역내총생산(시장가격)  13157700   인천광역시
# 7       남동구  지역내총생산(시장가격)  17562722   인천광역시
# 8       부평구  지역내총생산(시장가격)  10937058   인천광역시
# 9       계양구  지역내총생산(시장가격)   5128909   인천광역시
# 10       서구  지역내총생산(시장가격)  21789831   인천광역시

# %%
광주.head()
# Out:
#    시군구별         경제활동별      2021
# 0  시군구별         경제활동별     당해년가격
# 1    동구  지역내총생산(시장가격)   3783688
# 2    서구  지역내총생산(시장가격)  10368148
# 3    남구  지역내총생산(시장가격)   3399618
# 4    북구  지역내총생산(시장가격)  11129153

# %%
광주.drop(0,axis=0, inplace=True)
광주.columns = ['행정구역시군구명', '내용', '금액']
광주['행정구역시도명'] = '광주광역시'
광주
# Out:
#   행정구역시군구명            내용        금액 행정구역시도명
# 1       동구  지역내총생산(시장가격)   3783688   광주광역시
# 2       서구  지역내총생산(시장가격)  10368148   광주광역시
# 3       남구  지역내총생산(시장가격)   3399618   광주광역시
# 4       북구  지역내총생산(시장가격)  11129153   광주광역시
# 5      광산구  지역내총생산(시장가격)  15061973   광주광역시

# %%
대전.head()
# Out:
#    시군구별         경제활동별      2021
# 0  시군구별         경제활동별     당해년가격
# 1    동구  지역내총생산(시장가격)   3686340
# 2    중구  지역내총생산(시장가격)   5299811
# 3    서구  지역내총생산(시장가격)  13191386
# 4   유성구  지역내총생산(시장가격)  16471660

# %%
대전.drop(0,axis=0, inplace=True)
대전.columns = ['행정구역시군구명', '내용', '금액']
대전['행정구역시도명'] = '대전광역시'
대전
# Out:
#   행정구역시군구명            내용        금액 행정구역시도명
# 1       동구  지역내총생산(시장가격)   3686340   대전광역시
# 2       중구  지역내총생산(시장가격)   5299811   대전광역시
# 3       서구  지역내총생산(시장가격)  13191386   대전광역시
# 4      유성구  지역내총생산(시장가격)  16471660   대전광역시
# 5      대덕구  지역내총생산(시장가격)   8067394   대전광역시

# %%
울산.head()
# Out:
#    구군별         경제활동별         2021
# 0  구군별         경제활동별  당해년가격 (백만원)
# 1   중구  지역내총생산(시장가격)      4681237
# 2   남구  지역내총생산(시장가격)     32333988
# 3   동구  지역내총생산(시장가격)      5645088
# 4   북구  지역내총생산(시장가격)     12437053

# %%
울산.drop(0,axis=0, inplace=True)
울산.columns = ['행정구역시군구명', '내용', '금액']
울산['행정구역시도명'] = '울산광역시'
울산
# Out:
#   행정구역시군구명            내용        금액 행정구역시도명
# 1       중구  지역내총생산(시장가격)   4681237   울산광역시
# 2       남구  지역내총생산(시장가격)  32333988   울산광역시
# 3       동구  지역내총생산(시장가격)   5645088   울산광역시
# 4       북구  지역내총생산(시장가격)  12437053   울산광역시
# 5      울주군  지역내총생산(시장가격)  22876447   울산광역시

# %%
경기.head()
# Out:
#    행정구역(시·군)별         경제활동별      2021
# 0  행정구역(시·군)별         경제활동별     당해년가격
# 1         수원시  지역내총생산(시장가격)  35684685
# 2         성남시  지역내총생산(시장가격)  50302710
# 3        의정부시  지역내총생산(시장가격)   7388564
# 4         안양시  지역내총생산(시장가격)  18439904

# %%
경기.drop(0,axis=0, inplace=True)
경기.columns = ['행정구역시군구명', '내용', '금액']
경기['행정구역시도명'] = '경기도'
경기
# Out:
#    행정구역시군구명            내용        금액 행정구역시도명
# 1       수원시  지역내총생산(시장가격)  35684685     경기도
# 2       성남시  지역내총생산(시장가격)  50302710     경기도
# 3      의정부시  지역내총생산(시장가격)   7388564     경기도
# 4       안양시  지역내총생산(시장가격)  18439904     경기도
# 5       부천시  지역내총생산(시장가격)  17940553     경기도
# 6       광명시  지역내총생산(시장가격)   8074460     경기도
# 7       평택시  지역내총생산(시장가격)  35038757     경기도
# 8      동두천시  지역내총생산(시장가격)   1792963     경기도
# 9       안산시  지역내총생산(시장가격)  25717424     경기도
# 10      고양시  지역내총생산(시장가격)  22616950     경기도
# 11      과천시  지역내총생산(시장가격)   4650517     경기도
# 12      구리시  지역내총생산(시장가격)   3611223     경기도
# 13     남양주시  지역내총생산(시장가격)  13099866     경기도
# 14      오산시  지역내총생산(시장가격)   6031892     경기도
# 15      시흥시  지역내총생산(시장가격)  17801820     경기도
# 16      군포시  지역내총생산(시장가격)   7329556     경기도
# 17      의왕시  지역내총생산(시장가격)   4127736     경기도
# 18      하남시  지역내총생산(시장가격)   8087877     경기도
# 19      용인시  지역내총생산(시장가격)  35308886     경기도
# 20      파주시  지역내총생산(시장가격)  23932152     경기도
# ...

# %%
강원.head()
# Out:
#        경제활동별(1)  시군구별(1)     2021
# 0      경제활동별(1)  시군구별(1)    당해년가격
# 1  지역내총생산(시장가격)      춘천시  8462409
# 2  지역내총생산(시장가격)      원주시  9573324
# 3  지역내총생산(시장가격)      강릉시  6321485
# 4  지역내총생산(시장가격)      동해시  3353305

# %%
# 열 순서 통일
cols = 강원.columns.tolist()
cols[0], cols[1] = cols[1], cols[0]
강원 = 강원[cols]

# %%
강원.head()
# Out:
#    시군구별(1)      경제활동별(1)     2021
# 0  시군구별(1)      경제활동별(1)    당해년가격
# 1      춘천시  지역내총생산(시장가격)  8462409
# 2      원주시  지역내총생산(시장가격)  9573324
# 3      강릉시  지역내총생산(시장가격)  6321485
# 4      동해시  지역내총생산(시장가격)  3353305

# %%
강원.drop(0,axis=0, inplace=True)
강원.columns = ['행정구역시군구명', '내용', '금액']
강원['행정구역시도명'] = '강원도'
강원
# Out:
#    행정구역시군구명            내용       금액 행정구역시도명
# 1       춘천시  지역내총생산(시장가격)  8462409     강원도
# 2       원주시  지역내총생산(시장가격)  9573324     강원도
# 3       강릉시  지역내총생산(시장가격)  6321485     강원도
# 4       동해시  지역내총생산(시장가격)  3353305     강원도
# 5       태백시  지역내총생산(시장가격)  1020310     강원도
# 6       속초시  지역내총생산(시장가격)  1959973     강원도
# 7       삼척시  지역내총생산(시장가격)  2805066     강원도
# 8       홍천군  지역내총생산(시장가격)  2529264     강원도
# 9       횡성군  지역내총생산(시장가격)  1834222     강원도
# 10      영월군  지역내총생산(시장가격)  1347674     강원도
# 11      평창군  지역내총생산(시장가격)  1457943     강원도
# 12      정선군  지역내총생산(시장가격)  1333917     강원도
# 13      철원군  지역내총생산(시장가격)  2201383     강원도
# 14      화천군  지역내총생산(시장가격)  1641923     강원도
# 15      양구군  지역내총생산(시장가격)  1104871     강원도
# 16      인제군  지역내총생산(시장가격)  1767017     강원도
# 17      고성군  지역내총생산(시장가격)  1339210     강원도
# 18      양양군  지역내총생산(시장가격)  1153874     강원도

# %%
충북.head()
# Out:
#    시군구별         경제활동별      2021
# 0  시군구별         경제활동별     당해년가격
# 1   청주시  지역내총생산(시장가격)  38651298
# 2   충주시  지역내총생산(시장가격)   7846266
# 3   제천시  지역내총생산(시장가격)   3421532
# 4   보은군  지역내총생산(시장가격)   1220756

# %%
충북.drop(0,axis=0, inplace=True)
충북.columns = ['행정구역시군구명', '내용', '금액']
충북['행정구역시도명'] = '충청북도'
충북
# Out:
#    행정구역시군구명            내용        금액 행정구역시도명
# 1       청주시  지역내총생산(시장가격)  38651298    충청북도
# 2       충주시  지역내총생산(시장가격)   7846266    충청북도
# 3       제천시  지역내총생산(시장가격)   3421532    충청북도
# 4       보은군  지역내총생산(시장가격)   1220756    충청북도
# 5       옥천군  지역내총생산(시장가격)   1498401    충청북도
# 6       영동군  지역내총생산(시장가격)   1263467    충청북도
# 7       증평군  지역내총생산(시장가격)   1327159    충청북도
# 8       진천군  지역내총생산(시장가격)   8105363    충청북도
# 9       괴산군  지역내총생산(시장가격)   1518123    충청북도
# 10      음성군  지역내총생산(시장가격)   9243774    충청북도
# 11      단양군  지역내총생산(시장가격)   1193247    충청북도

# %%
충남.head()
# Out:
#    시군구별         경제활동별      2021
# 0  시군구별         경제활동별     당해년가격
# 1   천안시  지역내총생산(시장가격)  27894706
# 2   공주시  지역내총생산(시장가격)   4080692
# 3   보령시  지역내총생산(시장가격)   3852144
# 4   아산시  지역내총생산(시장가격)  31554788

# %%
충남.drop(0,axis=0, inplace=True)
충남.columns = ['행정구역시군구명', '내용', '금액']
충남['행정구역시도명'] = '충청남도'
충남
# Out:
#    행정구역시군구명            내용        금액 행정구역시도명
# 1       천안시  지역내총생산(시장가격)  27894706    충청남도
# 2       공주시  지역내총생산(시장가격)   4080692    충청남도
# 3       보령시  지역내총생산(시장가격)   3852144    충청남도
# 4       아산시  지역내총생산(시장가격)  31554788    충청남도
# 5       서산시  지역내총생산(시장가격)  20114038    충청남도
# 6       논산시  지역내총생산(시장가격)   4401371    충청남도
# 7       계룡시  지역내총생산(시장가격)   1710883    충청남도
# 8       당진시  지역내총생산(시장가격)  13246669    충청남도
# 9       금산군  지역내총생산(시장가격)   2310879    충청남도
# 10      부여군  지역내총생산(시장가격)   2050972    충청남도
# 11      서천군  지역내총생산(시장가격)   2406858    충청남도
# 12      청양군  지역내총생산(시장가격)   1320352    충청남도
# 13      홍성군  지역내총생산(시장가격)   3917314    충청남도
# 14      예산군  지역내총생산(시장가격)   3897521    충청남도
# 15      태안군  지역내총생산(시장가격)   2657260    충청남도

# %%
전북.head()
# Out:
#    시군구별         경제활동별      2021
# 0  시군구별         경제활동별     당해년가격
# 1   전주시  지역내총생산(시장가격)  16011015
# 2   군산시  지역내총생산(시장가격)  10507858
# 3   익산시  지역내총생산(시장가격)   8664971
# 4   정읍시  지역내총생산(시장가격)   3533350

# %%
전북.drop(0,axis=0, inplace=True)
전북.columns = ['행정구역시군구명', '내용', '금액']
전북['행정구역시도명'] = '전라북도'
전북
# Out:
#    행정구역시군구명            내용        금액 행정구역시도명
# 1       전주시  지역내총생산(시장가격)  16011015    전라북도
# 2       군산시  지역내총생산(시장가격)  10507858    전라북도
# 3       익산시  지역내총생산(시장가격)   8664971    전라북도
# 4       정읍시  지역내총생산(시장가격)   3533350    전라북도
# 5       남원시  지역내총생산(시장가격)   1911878    전라북도
# 6       김제시  지역내총생산(시장가격)   3288996    전라북도
# 7       완주군  지역내총생산(시장가격)   5233928    전라북도
# 8       진안군  지역내총생산(시장가격)    658361    전라북도
# 9       무주군  지역내총생산(시장가격)    753161    전라북도
# 10      장수군  지역내총생산(시장가격)    580290    전라북도
# 11      임실군  지역내총생산(시장가격)    880077    전라북도
# 12      순창군  지역내총생산(시장가격)    776059    전라북도
# 13      고창군  지역내총생산(시장가격)   1670372    전라북도
# 14      부안군  지역내총생산(시장가격)   1485539    전라북도

# %%
전남.head()
# Out:
#    시군구별         경제활동별         2021
# 0  시군구별         경제활동별  당해년가격 (백만원)
# 1   목포시  지역내총생산(시장가격)      4594091
# 2   여수시  지역내총생산(시장가격)     30566998
# 3   순천시  지역내총생산(시장가격)      6383982
# 4   나주시  지역내총생산(시장가격)      5380719

# %%
전남.drop(0,axis=0, inplace=True)
전남.columns = ['행정구역시군구명', '내용', '금액']
전남['행정구역시도명'] = '전라남도'
전남
# Out:
#    행정구역시군구명            내용        금액 행정구역시도명
# 1       목포시  지역내총생산(시장가격)   4594091    전라남도
# 2       여수시  지역내총생산(시장가격)  30566998    전라남도
# 3       순천시  지역내총생산(시장가격)   6383982    전라남도
# 4       나주시  지역내총생산(시장가격)   5380719    전라남도
# 5       광양시  지역내총생산(시장가격)  13834369    전라남도
# 6       담양군  지역내총생산(시장가격)   1552619    전라남도
# 7       곡성군  지역내총생산(시장가격)   1154432    전라남도
# 8       구례군  지역내총생산(시장가격)    616413    전라남도
# 9       고흥군  지역내총생산(시장가격)   1644323    전라남도
# 10      보성군  지역내총생산(시장가격)   1041673    전라남도
# 11      화순군  지역내총생산(시장가격)   1906431    전라남도
# 12      장흥군  지역내총생산(시장가격)   1091632    전라남도
# 13      강진군  지역내총생산(시장가격)   1012211    전라남도
# 14      해남군  지역내총생산(시장가격)   2336840    전라남도
# 15      영암군  지역내총생산(시장가격)   3280495    전라남도
# 16      무안군  지역내총생산(시장가격)   3558764    전라남도
# 17      함평군  지역내총생산(시장가격)   1108784    전라남도
# 18      영광군  지역내총생산(시장가격)   1930076    전라남도
# 19      장성군  지역내총생산(시장가격)   2071864    전라남도
# 20      완도군  지역내총생산(시장가격)   1183003    전라남도
# ...

# %%
경북.head()
# Out:
#    행정구역별(시군)           산업별          2021
# 0  행정구역별(시군)           산업별  당해년 가격 (백만원)
# 1        포항시  지역내총생산(시장가격)      23813078
# 2        경주시  지역내총생산(시장가격)      11405637
# 3        김천시  지역내총생산(시장가격)       5797343
# 4        안동시  지역내총생산(시장가격)       5800551

# %%
경북.drop(0,axis=0, inplace=True)
경북.columns = ['행정구역시군구명', '내용', '금액']
경북['행정구역시도명'] = '경상북도'
경북
# Out:
#    행정구역시군구명            내용        금액 행정구역시도명
# 1       포항시  지역내총생산(시장가격)  23813078    경상북도
# 2       경주시  지역내총생산(시장가격)  11405637    경상북도
# 3       김천시  지역내총생산(시장가격)   5797343    경상북도
# 4       안동시  지역내총생산(시장가격)   5800551    경상북도
# 5       구미시  지역내총생산(시장가격)  26427352    경상북도
# 6       영주시  지역내총생산(시장가격)   3400473    경상북도
# 7       영천시  지역내총생산(시장가격)   4268657    경상북도
# 8       상주시  지역내총생산(시장가격)   2737081    경상북도
# 9       문경시  지역내총생산(시장가격)   1860692    경상북도
# 10      경산시  지역내총생산(시장가격)   8379801    경상북도
# 11      군위군  지역내총생산(시장가격)    995905    경상북도
# 12      의성군  지역내총생산(시장가격)   1471875    경상북도
# 13      청송군  지역내총생산(시장가격)    756705    경상북도
# 14      영양군  지역내총생산(시장가격)    494412    경상북도
# 15      영덕군  지역내총생산(시장가격)    915689    경상북도
# 16      청도군  지역내총생산(시장가격)   1219171    경상북도
# 17      고령군  지역내총생산(시장가격)   1719068    경상북도
# 18      성주군  지역내총생산(시장가격)   2454087    경상북도
# 19      칠곡군  지역내총생산(시장가격)   4271737    경상북도
# 20      예천군  지역내총생산(시장가격)   1370332    경상북도
# ...

# %%
경남.head()
# Out:
#    시군구별(1)      경제활동별(1)         2021
# 0  시군구별(1)      경제활동별(1)  당해년가격 (백만원)
# 1      창원시  지역내총생산(시장가격)     39217248
# 2      진주시  지역내총생산(시장가격)      8764423
# 3      통영시  지역내총생산(시장가격)      3181635
# 4      사천시  지역내총생산(시장가격)      4650021

# %%
경남.drop(0,axis=0, inplace=True)
경남.columns = ['행정구역시군구명', '내용', '금액']
경남['행정구역시도명'] = '경상남도'
경남
# Out:
#    행정구역시군구명            내용        금액 행정구역시도명
# 1       창원시  지역내총생산(시장가격)  39217248    경상남도
# 2       진주시  지역내총생산(시장가격)   8764423    경상남도
# 3       통영시  지역내총생산(시장가격)   3181635    경상남도
# 4       사천시  지역내총생산(시장가격)   4650021    경상남도
# 5       김해시  지역내총생산(시장가격)  15627489    경상남도
# 6       밀양시  지역내총생산(시장가격)   3212528    경상남도
# 7       거제시  지역내총생산(시장가격)   9211975    경상남도
# 8       양산시  지역내총생산(시장가격)  11007784    경상남도
# 9       의령군  지역내총생산(시장가격)    974946    경상남도
# 10      함안군  지역내총생산(시장가격)   3973418    경상남도
# 11      창녕군  지역내총생산(시장가격)   2765523    경상남도
# 12      고성군  지역내총생산(시장가격)   2212317    경상남도
# 13      남해군  지역내총생산(시장가격)   1176264    경상남도
# 14      하동군  지역내총생산(시장가격)   1968174    경상남도
# 15      산청군  지역내총생산(시장가격)   1095046    경상남도
# 16      함양군  지역내총생산(시장가격)   1082102    경상남도
# 17      거창군  지역내총생산(시장가격)   1645349    경상남도
# 18      합천군  지역내총생산(시장가격)   1183426    경상남도

# %%
제주.head()
# Out:
#    시군구별         경제활동별      2021
# 0  시군구별         경제활동별     당해년가격
# 1   제주시  지역내총생산(시장가격)  14681431
# 2  서귀포시  지역내총생산(시장가격)   5506072

# %%
제주.drop(0,axis=0, inplace=True)
제주.columns = ['행정구역시군구명', '내용', '금액']
제주['행정구역시도명'] = '제주특별자치도'
제주
# Out:
#   행정구역시군구명            내용        금액  행정구역시도명
# 1      제주시  지역내총생산(시장가격)  14681431  제주특별자치도
# 2     서귀포시  지역내총생산(시장가격)   5506072  제주특별자치도

# %% [markdown]
# - 세종시가 없음
# - 그외의 250개 기준과 달라 누락된 데이터 존재(수원시 - 장안구, 팔달구, 권선구)

# %%
result = pd.concat([서울, 부산, 대구, 인천, 광주, 대전, 울산, 경기, 강원, 충북, 충남, 전북, 전남, 경북, 경남, 제주], axis=0)

# %%
result = result.reset_index(drop=True)

# %%
result
# Out:
#     행정구역시군구명            내용        금액  행정구역시도명
# 0        종로구  지역내총생산(시장가격)  35719537    서울특별시
# 1         중구  지역내총생산(시장가격)  61342710    서울특별시
# 2        용산구  지역내총생산(시장가격)  13294640    서울특별시
# 3        성동구  지역내총생산(시장가격)  13999893    서울특별시
# 4        광진구  지역내총생산(시장가격)   6554954    서울특별시
# ..       ...           ...       ...      ...
# 223      함양군  지역내총생산(시장가격)   1082102     경상남도
# 224      거창군  지역내총생산(시장가격)   1645349     경상남도
# 225      합천군  지역내총생산(시장가격)   1183426     경상남도
# 226      제주시  지역내총생산(시장가격)  14681431  제주특별자치도
# 227     서귀포시  지역내총생산(시장가격)   5506072  제주특별자치도
#
# [228 rows x 4 columns]

# %%
# 열 순서 재조정
cols = result.columns.tolist()
cols = [cols[3]] + cols[:3]

result = result[cols]

# %%
result
# Out:
#      행정구역시도명 행정구역시군구명            내용        금액
# 0      서울특별시      종로구  지역내총생산(시장가격)  35719537
# 1      서울특별시       중구  지역내총생산(시장가격)  61342710
# 2      서울특별시      용산구  지역내총생산(시장가격)  13294640
# 3      서울특별시      성동구  지역내총생산(시장가격)  13999893
# 4      서울특별시      광진구  지역내총생산(시장가격)   6554954
# ..       ...      ...           ...       ...
# 223     경상남도      함양군  지역내총생산(시장가격)   1082102
# 224     경상남도      거창군  지역내총생산(시장가격)   1645349
# 225     경상남도      합천군  지역내총생산(시장가격)   1183426
# 226  제주특별자치도      제주시  지역내총생산(시장가격)  14681431
# 227  제주특별자치도     서귀포시  지역내총생산(시장가격)   5506072
#
# [228 rows x 4 columns]

# %%
import os

# 현재 작업 디렉토리 출력
current_directory = os.getcwd()
print("현재 작업 디렉토리:", current_directory)
# Out:
# 현재 작업 디렉토리: /content

# %%
# result.to_csv('./drive/MyDrive/mulcam_bigdata/2024통계데이터공모전/기획_데이터수집/성원님/temp/지역내총생산_통합본.csv',index=False)

# %% [markdown]
# 세종시 데이터 추가

# %%
path = '/content/drive/MyDrive/mulcam_bigdata/2024통계데이터공모전/기획_데이터수집/성원님/temp/지역내총생산_통합본.csv'
res = pd.read_csv(path)

# %%
세종 = {'행정구역시도명' : '세종특별자치시', '행정구역시군구명' : '세종특별자치시', '내용' : '지역내총생산(시장가격)', '금액' : 12509400}
세종_df = pd.DataFrame(세종, index=[228])

# %%
res = pd.concat([res, 세종_df], axis=0)

# %%
res
# Out:
#      행정구역시도명 행정구역시군구명            내용        금액
# 0      서울특별시      종로구  지역내총생산(시장가격)  35719537
# 1      서울특별시       중구  지역내총생산(시장가격)  61342710
# 2      서울특별시      용산구  지역내총생산(시장가격)  13294640
# 3      서울특별시      성동구  지역내총생산(시장가격)  13999893
# 4      서울특별시      광진구  지역내총생산(시장가격)   6554954
# ..       ...      ...           ...       ...
# 224     경상남도      거창군  지역내총생산(시장가격)   1645349
# 225     경상남도      합천군  지역내총생산(시장가격)   1183426
# 226  제주특별자치도      제주시  지역내총생산(시장가격)  14681431
# 227  제주특별자치도     서귀포시  지역내총생산(시장가격)   5506072
# 228  세종특별자치시  세종특별자치시  지역내총생산(시장가격)  12509400
#
# [229 rows x 4 columns]

# %%
# 세종시 데이터 추가본 저장
# res.to_csv('./drive/MyDrive/mulcam_bigdata/2024통계데이터공모전/기획_데이터수집/성원님/temp/지역내총생산_통합본.csv',index=False)

# %%
path = '/content/drive/MyDrive/mulcam_bigdata/2024통계데이터공모전/기획_데이터수집/성원님/temp/지역내총생산_통합본.csv'
res = pd.read_csv(path)
res
# Out:
#      행정구역시도명 행정구역시군구명            내용        금액
# 0      서울특별시      종로구  지역내총생산(시장가격)  35719537
# 1      서울특별시       중구  지역내총생산(시장가격)  61342710
# 2      서울특별시      용산구  지역내총생산(시장가격)  13294640
# 3      서울특별시      성동구  지역내총생산(시장가격)  13999893
# 4      서울특별시      광진구  지역내총생산(시장가격)   6554954
# ..       ...      ...           ...       ...
# 224     경상남도      거창군  지역내총생산(시장가격)   1645349
# 225     경상남도      합천군  지역내총생산(시장가격)   1183426
# 226  제주특별자치도      제주시  지역내총생산(시장가격)  14681431
# 227  제주특별자치도     서귀포시  지역내총생산(시장가격)   5506072
# 228  세종특별자치시  세종특별자치시  지역내총생산(시장가격)  12509400
#
# [229 rows x 4 columns]
