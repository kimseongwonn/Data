# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.simplefilter(action='ignore')

# %% [markdown]
# 시도별 면적 데이터 불러오기

# %%
path = '/content/drive/MyDrive/mulcam_bigdata/2024통계데이터공모전/기획_데이터수집/성원님/Data/20년 기준 지역별 면적(시도별).csv'
면적 = pd.read_csv(path)

# %%
df_area = 면적.copy()

# %%
df_area.columns
# Out:
# Index(['행정구역별(1)', '행정구역별(2)', '인구현황별(1)', '2020'], dtype='object')

# %%
# 편집할 면적 데이터 복사본
df_area
# Out:
#     행정구역별(1) 행정구역별(2) 인구현황별(1)       2020
# 0         총계       소계   면적 (㎢)  100457.70
# 1      서울특별시       소계   면적 (㎢)     605.23
# 2      서울특별시      종로구   면적 (㎢)      23.91
# 3      서울특별시       중구   면적 (㎢)       9.96
# 4      서울특별시      용산구   면적 (㎢)      21.87
# ..       ...      ...      ...        ...
# 241     경상남도      거창군   면적 (㎢)     803.38
# 242     경상남도      합천군   면적 (㎢)     983.04
# 243  제주특별자치도       소계   면적 (㎢)    1850.20
# 244  제주특별자치도      제주시   면적 (㎢)     978.70
# 245  제주특별자치도     서귀포시   면적 (㎢)     871.50
#
# [246 rows x 4 columns]

# %%
# 소계 데이터 값을 가진 행 제거
# 소계로 자르니 세종자치시 사라짐
# 조건 or 로 추가
df_area = df_area[(df_area['행정구역별(2)'] != '소계') | (df_area['행정구역별(1)'] == '세종특별자치시')]

# %%
df_area['행정구역별(1)'].unique()
# Out:
# array(['서울특별시', '부산광역시', '대구광역시', '인천광역시', '광주광역시', '대전광역시', '울산광역시',
#        '세종특별자치시', '경기도', '강원특별자치도', '충청북도', '충청남도', '전라북도', '전라남도',
#        '경상북도', '경상남도', '제주특별자치도'], dtype=object)

# %%
# 세종특별자치시 살아남은 것 확인
df_area[df_area['행정구역별(1)'] == '세종특별자치시']
# Out:
#    행정구역별(1) 행정구역별(2) 인구현황별(1)   2020
# 82  세종특별자치시       소계   면적 (㎢)  465.0

# %%
# 매핑 기준 딕셔너리 정의
map = {
    "서울특별시": "서울",
    "부산광역시": "부산",
    "대구광역시": "대구",
    "인천광역시": "인천",
    "광주광역시": "광주",
    "대전광역시": "대전",
    "울산광역시": "울산",
    "세종특별자치시": "세종특별자치시",
    "경기도": "경기",
    "강원특별자치도": "강원",
    "충청북도": "충북",
    "충청남도": "충남",
    "전라북도": "전북",
    "전라남도": "전남",
    "경상북도": "경북",
    "경상남도": "경남",
    "제주특별자치도": "제주"
}

# %%
# 매핑 딕셔너리로 값 다시 매핑해줄 새로운 '시도' 열 생성
df_area['시도'] = df_area['행정구역별(1)']

# %%
df_area = df_area.reset_index(drop=True)
df_area
# Out:
#     행정구역별(1) 행정구역별(2) 인구현황별(1)    2020       시도
# 0      서울특별시      종로구   면적 (㎢)   23.91    서울특별시
# 1      서울특별시       중구   면적 (㎢)    9.96    서울특별시
# 2      서울특별시      용산구   면적 (㎢)   21.87    서울특별시
# 3      서울특별시      성동구   면적 (㎢)   16.86    서울특별시
# 4      서울특별시      광진구   면적 (㎢)   17.06    서울특별시
# ..       ...      ...      ...     ...      ...
# 224     경상남도      함양군   면적 (㎢)  725.50     경상남도
# 225     경상남도      거창군   면적 (㎢)  803.38     경상남도
# 226     경상남도      합천군   면적 (㎢)  983.04     경상남도
# 227  제주특별자치도      제주시   면적 (㎢)  978.70  제주특별자치도
# 228  제주특별자치도     서귀포시   면적 (㎢)  871.50  제주특별자치도
#
# [229 rows x 5 columns]

# %%
# 시도 컬럼 map 딕셔너리 기준으로 변경하기
map_keys = map.keys()

for key in map_keys :
    for i in range(len(df_area['시도'].values)) :
        if df_area['시도'][i] == key :
            df_area['시도'][i] = map[key]

# %%
df_area
# Out:
#     행정구역별(1) 행정구역별(2) 인구현황별(1)    2020  시도
# 0      서울특별시      종로구   면적 (㎢)   23.91  서울
# 1      서울특별시       중구   면적 (㎢)    9.96  서울
# 2      서울특별시      용산구   면적 (㎢)   21.87  서울
# 3      서울특별시      성동구   면적 (㎢)   16.86  서울
# 4      서울특별시      광진구   면적 (㎢)   17.06  서울
# ..       ...      ...      ...     ...  ..
# 224     경상남도      함양군   면적 (㎢)  725.50  경남
# 225     경상남도      거창군   면적 (㎢)  803.38  경남
# 226     경상남도      합천군   면적 (㎢)  983.04  경남
# 227  제주특별자치도      제주시   면적 (㎢)  978.70  제주
# 228  제주특별자치도     서귀포시   면적 (㎢)  871.50  제주
#
# [229 rows x 5 columns]

# %%
# '행정구역시군구명' 새로운 열 생성 >> 인구 데이터와 컬럼명과 형식 통일
df_area['행정구역시군구명'] = df_area['시도'] + ' ' + df_area['행정구역별(2)']

# %%
df_area
# Out:
#     행정구역별(1) 행정구역별(2) 인구현황별(1)    2020  시도 행정구역시군구명
# 0      서울특별시      종로구   면적 (㎢)   23.91  서울   서울 종로구
# 1      서울특별시       중구   면적 (㎢)    9.96  서울    서울 중구
# 2      서울특별시      용산구   면적 (㎢)   21.87  서울   서울 용산구
# 3      서울특별시      성동구   면적 (㎢)   16.86  서울   서울 성동구
# 4      서울특별시      광진구   면적 (㎢)   17.06  서울   서울 광진구
# ..       ...      ...      ...     ...  ..      ...
# 224     경상남도      함양군   면적 (㎢)  725.50  경남   경남 함양군
# 225     경상남도      거창군   면적 (㎢)  803.38  경남   경남 거창군
# 226     경상남도      합천군   면적 (㎢)  983.04  경남   경남 합천군
# 227  제주특별자치도      제주시   면적 (㎢)  978.70  제주   제주 제주시
# 228  제주특별자치도     서귀포시   면적 (㎢)  871.50  제주  제주 서귀포시
#
# [229 rows x 6 columns]

# %% [markdown]
# ----
# 여기까지 면적 데이터 1차 전처리
# - 면적데이터 '시도', '행정구역시군구명' 컬럼 생성 >> 인구 데이터와 동일한 컬럼명과 형식

# %% [markdown]
# 시군구 인구 데이터

# %%
path2 ='/content/drive/MyDrive/mulcam_bigdata/2024통계데이터공모전/기획_데이터수집/건우님/통계자료/(전처리함)2020_2%_시군구별_소아청소년 인구.csv'

# %%
인구 = pd.read_csv(path2)

# %%
# 편집할 인구 데이터 복사본
df_people = 인구.copy()

# %%
df_people['행정구역시군구명'].nunique()
# Out:
# 250

# %%
df_people['행정구역시군구명'].unique()
# Out:
# array(['서울 종로구', '서울 중구', '서울 용산구', '서울 성동구', '서울 광진구', '서울 동대문구',
#        '서울 중랑구', '서울 성북구', '서울 강북구', '서울 도봉구', '서울 노원구', '서울 은평구',
#        '서울 서대문구', '서울 마포구', '서울 양천구', '서울 강서구', '서울 구로구', '서울 금천구',
#        '서울 영등포구', '서울 동작구', '서울 관악구', '서울 서초구', '서울 강남구', '서울 송파구',
#        '서울 강동구', '부산 중구', '부산 서구', '부산 동구', '부산 영도구', '부산 부산진구', '부산 동래구',
#        '부산 남구', '부산 북구', '부산 해운대구', '부산 사하구', '부산 금정구', '부산 강서구',
#        '부산 연제구', '부산 수영구', '부산 사상구', '부산 기장군', '대구 중구', '대구 동구', '대구 서구',
#        '대구 남구', '대구 북구', '대구 수성구', '대구 달서구', '대구 달성군', '인천 중구', '인천 동구',
#        '인천 연수구', '인천 남동구', '인천 부평구', '인천 계양구', '인천 서구', '인천 미추홀구',
#        '인천 강화군', '인천 옹진군', '광주 동구', '광주 서구', '광주 남구', '광주 북구', '광주 광산구',
#        '대전 동구', '대전 중구', '대전 서구', '대전 유성구', '대전 대덕구', '울산 중구', '울산 남구',
#        '울산 동구', '울산 북구', '울산 울주군', '세종특별자치시', '경기 장안구', '경기 권선구',
#        '경기 팔달구', '경기 영통구', '경기 수정구', '경기 중원구', '경기 분당구', '경기 의정부시',
#        '경기 만안구', '경기 동안구', '경기 부천시', '경기 광명시', '경기 평택시', '경기 동두천시',
# ...

# %%
# 시군구 코드별 소아 인원 수 그룹화 데이터 프레임
df_people_group = pd.DataFrame(df_people.groupby('시군구코드')['시군구코드'].count())
df_people_group
# Out:
#        시군구코드
# 시군구코드
# 11010    521
# 11020    416
# 11030    567
# 11040    552
# 11050    677
# ...      ...
# 38380    182
# 38390    168
# 38400    179
# 39010   1208
# 39020    479
#
# [250 rows x 1 columns]

# %%
# 열 이름 설정 및 인덱스 초기화
df_people_group.columns = ['소아인구수']
df_people_group = df_people_group.reset_index()

# %%
df_people_group
# Out:
#      시군구코드  소아인구수
# 0    11010    521
# 1    11020    416
# 2    11030    567
# 3    11040    552
# 4    11050    677
# ..     ...    ...
# 245  38380    182
# 246  38390    168
# 247  38400    179
# 248  39010   1208
# 249  39020    479
#
# [250 rows x 2 columns]

# %% [markdown]
# ----
# 여기까지 인구 데이터 1차 전처리
# - 시군구 코드별 소아 인구수 추출

# %% [markdown]
# 면적 데이터와 인구 데이터의 행정구역시군구명 수가 다르다

# %%
len(df_area['행정구역시군구명'].unique())
# Out:
# 229

# %%
len(df_people['행정구역시군구명'].unique())
# Out:
# 250

# %%
df_area['행정구역시군구명'].unique()
# Out:
# array(['서울 종로구', '서울 중구', '서울 용산구', '서울 성동구', '서울 광진구', '서울 동대문구',
#        '서울 중랑구', '서울 성북구', '서울 강북구', '서울 도봉구', '서울 노원구', '서울 은평구',
#        '서울 서대문구', '서울 마포구', '서울 양천구', '서울 강서구', '서울 구로구', '서울 금천구',
#        '서울 영등포구', '서울 동작구', '서울 관악구', '서울 서초구', '서울 강남구', '서울 송파구',
#        '서울 강동구', '부산 중구', '부산 서구', '부산 동구', '부산 영도구', '부산 부산진구', '부산 동래구',
#        '부산 남구', '부산 북구', '부산 해운대구', '부산 사하구', '부산 금정구', '부산 강서구',
#        '부산 연제구', '부산 수영구', '부산 사상구', '부산 기장군', '대구 중구', '대구 동구', '대구 서구',
#        '대구 남구', '대구 북구', '대구 수성구', '대구 달서구', '대구 달성군', '인천 중구', '인천 동구',
#        '인천 미추홀구', '인천 연수구', '인천 남동구', '인천 부평구', '인천 계양구', '인천 서구',
#        '인천 강화군', '인천 옹진군', '광주 동구', '광주 서구', '광주 남구', '광주 북구', '광주 광산구',
#        '대전 동구', '대전 중구', '대전 서구', '대전 유성구', '대전 대덕구', '울산 중구', '울산 남구',
#        '울산 동구', '울산 북구', '울산 울주군', '세종특별자치시 소계', '경기 수원시', '경기 성남시',
#        '경기 의정부시', '경기 안양시', '경기 부천시', '경기 광명시', '경기 평택시', '경기 동두천시',
# ...

# %%
df_people['행정구역시군구명'].unique()
# Out:
# array(['서울 종로구', '서울 중구', '서울 용산구', '서울 성동구', '서울 광진구', '서울 동대문구',
#        '서울 중랑구', '서울 성북구', '서울 강북구', '서울 도봉구', '서울 노원구', '서울 은평구',
#        '서울 서대문구', '서울 마포구', '서울 양천구', '서울 강서구', '서울 구로구', '서울 금천구',
#        '서울 영등포구', '서울 동작구', '서울 관악구', '서울 서초구', '서울 강남구', '서울 송파구',
#        '서울 강동구', '부산 중구', '부산 서구', '부산 동구', '부산 영도구', '부산 부산진구', '부산 동래구',
#        '부산 남구', '부산 북구', '부산 해운대구', '부산 사하구', '부산 금정구', '부산 강서구',
#        '부산 연제구', '부산 수영구', '부산 사상구', '부산 기장군', '대구 중구', '대구 동구', '대구 서구',
#        '대구 남구', '대구 북구', '대구 수성구', '대구 달서구', '대구 달성군', '인천 중구', '인천 동구',
#        '인천 연수구', '인천 남동구', '인천 부평구', '인천 계양구', '인천 서구', '인천 미추홀구',
#        '인천 강화군', '인천 옹진군', '광주 동구', '광주 서구', '광주 남구', '광주 북구', '광주 광산구',
#        '대전 동구', '대전 중구', '대전 서구', '대전 유성구', '대전 대덕구', '울산 중구', '울산 남구',
#        '울산 동구', '울산 북구', '울산 울주군', '세종특별자치시', '경기 장안구', '경기 권선구',
#        '경기 팔달구', '경기 영통구', '경기 수정구', '경기 중원구', '경기 분당구', '경기 의정부시',
#        '경기 만안구', '경기 동안구', '경기 부천시', '경기 광명시', '경기 평택시', '경기 동두천시',
# ...

# %%
# 면적과 인구 데이터의 행정구역시군구명 Series 생성
면적_data = pd.Series(df_area['행정구역시군구명'].unique())
인구_data=pd.Series(df_people['행정구역시군구명'].unique())

# %%
면적_data
# Out:
# 0       서울 종로구
# 1        서울 중구
# 2       서울 용산구
# 3       서울 성동구
# 4       서울 광진구
#         ...
# 224     경남 함양군
# 225     경남 거창군
# 226     경남 합천군
# 227     제주 제주시
# 228    제주 서귀포시
# Length: 229, dtype: object

# %%
인구_data
# Out:
# 0       서울 종로구
# 1        서울 중구
# 2       서울 용산구
# 3       서울 성동구
# 4       서울 광진구
#         ...
# 245     경남 함양군
# 246     경남 거창군
# 247     경남 합천군
# 248     제주 제주시
# 249    제주 서귀포시
# Length: 250, dtype: object

# %%
# 인구 데이터 행정구역시군구명 Series와 면적 데이터 행정구역시군구명 Series 를 비교하여 차이 21개 원인 데이터 추출

# 겹치는 데이터값 담을 리스트
in_true = []
# 차이나는 데이터값 담을 리스트
in_false = []

for i in range(len(인구_data)):
    if 면적_data.isin([인구_data[i]]).any():
        in_true.append(인구_data[i])
    else:
        in_false.append(인구_data[i])

# %%
len(in_true)
# Out:
# 217

# %%
len(in_false)
# Out:
# 33

# %%
in_false

# 원인1
# '경기 장안구','경기 권선구','경기 팔달구','경기 영통구','경기 수정구' >> 경기 수원시
# '경기 중원구','경기 분당구' >> 경기 성남시
# '경기 만안구','경기 동안구' >> 경기 안양시
# '경기 상록구','경기 단원구' >> 경기 안산시
# '경기 덕양구','경기 일산동구','경기 일산서구' >> 경기 고양시
# '경기 처인구','경기 기흥구','경기 수지구' >> 경기 용인시
# '충북 상당구','충북 서원구','충북 흥덕구','충북 청원구 >> 충북 청주시
# '충남 동남구','충남 서북구' >> 충북 천안시
# '전북 완산구','전북 덕진구' >> 전북 전주시
# '경북 포항시 남구','경북 포항시 북구' >> 경북 포항시
# '경남 창원시 의창구','경남 창원시 성산구','경남 창원시 마산합포구','경남 창원시 마산회원구','경남 창원시 진해구' >> 경남 창원시

# 면적 데이터의 경우 시 단위가 최하위 단위이고 인구 데이터의 경우 구단위가 최하위 단위인 곳이 존재
# 따라서 인구 데이터에서 구단위로 존재하는 32개를 상위 시단위 11개로 묶음

# 원인2
# '세종특별자치시' >> '세종특별자치시 소계'
# 면적 데이터에서 수정해야함

# 217개 + 11개(원인1) + 1개(원인2) = 229개 >> 데이터 일치
# Out:
# ['세종특별자치시',
#  '경기 장안구',
#  '경기 권선구',
#  '경기 팔달구',
#  '경기 영통구',
#  '경기 수정구',
#  '경기 중원구',
#  '경기 분당구',
#  '경기 만안구',
#  '경기 동안구',
#  '경기 상록구',
#  '경기 단원구',
#  '경기 덕양구',
#  '경기 일산동구',
#  '경기 일산서구',
#  '경기 처인구',
#  '경기 기흥구',
#  '경기 수지구',
#  '충북 상당구',
#  '충북 서원구',
#  '충북 흥덕구',
#  '충북 청원구',
#  '충남 동남구',
#  '충남 서북구',
#  '전북 완산구',
#  '전북 덕진구',
#  '경북 포항시 남구',
#  '경북 포항시 북구',
#  '경남 창원시 의창구',
#  '경남 창원시 성산구',
#  '경남 창원시 마산합포구',
#  '경남 창원시 마산회원구',
#  '경남 창원시 진해구']

# %% [markdown]
# 원인 2 해결

# %%
# 원인 2 해결
df_area.loc[74, '행정구역시군구명'] = '세종특별자치시'
df_area.loc[74, '행정구역시군구명']
# Out:
# '세종특별자치시'

# %% [markdown]
# 원인 1 해결

# %%
# 원인 1 해결용 딕셔너리 정의
map_si = {
    '경기 수원시' : ['경기 장안구','경기 권선구','경기 팔달구'],
    '경기 성남시' : ['경기 중원구','경기 분당구'],
    '경기 안양시' : ['경기 만안구','경기 동안구'],
    '경기 안산시' : ['경기 상록구','경기 단원구'],
    '경기 고양시' : ['경기 덕양구','경기 일산동구','경기 일산서구'],
    '경기 용인시' : ['경기 처인구','경기 기흥구','경기 수지구'],
    '충북 청주시' : ['충북 상당구','충북 서원구','충북 흥덕구','충북 청원구'],
    '충북 천안시' : ['충남 동남구','충남 서북구'],
    '전북 전주시' : ['전북 완산구','전북 덕진구'],
    '경북 포항시' : ['경북 포항시 남구','경북 포항시 북구'],
    '경남 창원시' : ['경남 창원시 의창구','경남 창원시 성산구','경남 창원시 마산합포구','경남 창원시 마산회원구','경남 창원시 진해구'],
}

# %% [markdown]
# 행정구역시군구명에 따른 시군구코드 통합 필요

# %% [markdown]
# 경기 장안구, 경기 팔달구 >> 둘다 수원시인데 시군구 코드가 세분화되어 있음
# - 면적 데이터에서는 경기 수원시로 나타나지고 인구 데이터에서는 위와 같이 세분화 되어 있음

# %%
df_people[df_people['행정구역시군구명'] == '경기 장안구']['시군구코드'].iloc[0]
# Out:
# 31011

# %%
df_people[df_people['행정구역시군구명'] == '경기 팔달구']['시군구코드'].iloc[0]
# Out:
# 31013

# %%
map_si['경기 수원시'][0]
# Out:
# '경기 장안구'

# %%
list(map_si.keys())
# Out:
# ['경기 수원시',
#  '경기 성남시',
#  '경기 안양시',
#  '경기 안산시',
#  '경기 고양시',
#  '경기 용인시',
#  '충북 청주시',
#  '충북 천안시',
#  '전북 전주시',
#  '경북 포항시',
#  '경남 창원시']

# %%
# 원인 1 values 시군구코드 알아내기

map_si_edit = {}

for key in list(map_si.keys()):
    for i in range(len(map_si[key])):
        map_si_edit[map_si[key][i]] = df_people[df_people['행정구역시군구명'] == map_si[key][i]]['시군구코드'].iloc[0]

# %%
map_si_edit
# Out:
# {'경기 장안구': 31011,
#  '경기 권선구': 31012,
#  '경기 팔달구': 31013,
#  '경기 중원구': 31022,
#  '경기 분당구': 31023,
#  '경기 만안구': 31041,
#  '경기 동안구': 31042,
#  '경기 상록구': 31091,
#  '경기 단원구': 31092,
#  '경기 덕양구': 31101,
#  '경기 일산동구': 31103,
#  '경기 일산서구': 31104,
#  '경기 처인구': 31191,
#  '경기 기흥구': 31192,
#  '경기 수지구': 31193,
#  '충북 상당구': 33041,
#  '충북 서원구': 33042,
#  '충북 흥덕구': 33043,
#  '충북 청원구': 33044,
#  '충남 동남구': 34011,
#  '충남 서북구': 34012,
#  '전북 완산구': 35011,
#  '전북 덕진구': 35012,
#  '경북 포항시 남구': 37011,
#  '경북 포항시 북구': 37012,
#  '경남 창원시 의창구': 38111,
#  '경남 창원시 성산구': 38112,
#  '경남 창원시 마산합포구': 38113,
#  '경남 창원시 마산회원구': 38114,
#  '경남 창원시 진해구': 38115}

# %% [markdown]
# 시 - 구 - 코드 구조로 연결된 딕셔너리 정의

# %%
map_si_num = {
    '경기 수원시' : {'경기 장안구': 31011,'경기 권선구': 31012,'경기 팔달구': 31013},
    '경기 성남시' : {'경기 중원구': 31022,'경기 분당구': 31023},
    '경기 안양시' : {'경기 만안구': 31041,'경기 동안구': 31042},
    '경기 안산시' : { '경기 상록구': 31091,'경기 단원구': 31092},
    '경기 고양시' : {'경기 일산동구': 31103,'경기 일산서구': 31104},
    '경기 용인시' : {'경기 처인구': 31191,'경기 기흥구': 31192,'경기 수지구': 31193},
    '충북 청주시' : {'충북 상당구': 33041,'충북 서원구': 33042,'충북 흥덕구': 33043,'충북 청원구': 33044},
    '충남 천안시' : {'충남 동남구': 34011,'충남 서북구': 34012},
    '전북 전주시' : {'전북 완산구': 35011,'전북 덕진구': 35012},
    '경북 포항시' : {'경북 포항시 남구': 37011,'경북 포항시 북구': 37012},
    '경남 창원시' : {'경남 창원시 의창구': 38111,'경남 창원시 성산구': 38112,'경남 창원시 마산합포구': 38113,'경남 창원시 마산회원구': 38114,'경남 창원시 진해구': 38115},
}

# %%
map_si_num['경기 수원시']['경기 장안구']
# Out:
# 31011

# %%
# 인구 데이터 {기준 행정구역시군구명 : 시군구코드} 딕셔너리 정의
temp_map = {}

for key in list(df_people['행정구역시군구명'].unique()):
    temp_map[key] = df_people[df_people['행정구역시군구명'] == key]['시군구코드'].iloc[0]
temp_map
# Out:
# {'서울 종로구': 11010,
#  '서울 중구': 11020,
#  '서울 용산구': 11030,
#  '서울 성동구': 11040,
#  '서울 광진구': 11050,
#  '서울 동대문구': 11060,
#  '서울 중랑구': 11070,
#  '서울 성북구': 11080,
#  '서울 강북구': 11090,
#  '서울 도봉구': 11100,
#  '서울 노원구': 11110,
#  '서울 은평구': 11120,
#  '서울 서대문구': 11130,
#  '서울 마포구': 11140,
#  '서울 양천구': 11150,
#  '서울 강서구': 11160,
#  '서울 구로구': 11170,
#  '서울 금천구': 11180,
#  '서울 영등포구': 11190,
#  '서울 동작구': 11200,
#  '서울 관악구': 11210,
#  '서울 서초구': 11220,
#  '서울 강남구': 11230,
#  '서울 송파구': 11240,
#  '서울 강동구': 11250,
#  '부산 중구': 21010,
#  '부산 서구': 21020,
#  '부산 동구': 21030,
#  '부산 영도구': 21040,
#  '부산 부산진구': 21050,
#  '부산 동래구': 21060,
#  '부산 남구': 21070,
#  '부산 북구': 21080,
#  '부산 해운대구': 21090,
#  '부산 사하구': 21100,
#  '부산 금정구': 21110,
#  '부산 강서구': 21120,
#  '부산 연제구': 21130,
#  '부산 수영구': 21140,
#  '부산 사상구': 21150,
#  '부산 기장군': 21310,
#  '대구 중구': 22010,
#  '대구 동구': 22020,
#  '대구 서구': 22030,
#  '대구 남구': 22040,
#  '대구 북구': 22050,
#  '대구 수성구': 22060,
#  '대구 달서구': 22070,
#  '대구 달성군': 22310,
#  '인천 중구': 23010,
# ...

# %%
df_area[:3]
# Out:
#   행정구역별(1) 행정구역별(2) 인구현황별(1)   2020  시도 행정구역시군구명
# 0    서울특별시      종로구   면적 (㎢)  23.91  서울   서울 종로구
# 1    서울특별시       중구   면적 (㎢)   9.96  서울    서울 중구
# 2    서울특별시      용산구   면적 (㎢)  21.87  서울   서울 용산구

# %%
# 시군구 코드를 넣어줄 새로운 열 생성
df_area['시군구코드'] = 0

# %%
temp_map_series = pd.Series(temp_map.keys())

# %%
# temp_map을 기준으로 면적 데이터 '시군구코드' 열에 값 할당
for i in range(len(df_area['행정구역시군구명'])):
    if temp_map_series.isin([df_area['행정구역시군구명'][i]]).any():
        df_area['시군구코드'][i] = temp_map[df_area['행정구역시군구명'][i]]
    else: # 원인 1 시도는 시군구 코드 0으로 처리
        df_area['시군구코드'][i] = 0

# %%
df_area
# Out:
#     행정구역별(1) 행정구역별(2) 인구현황별(1)    2020  시도 행정구역시군구명  시군구코드
# 0      서울특별시      종로구   면적 (㎢)   23.91  서울   서울 종로구  11010
# 1      서울특별시       중구   면적 (㎢)    9.96  서울    서울 중구  11020
# 2      서울특별시      용산구   면적 (㎢)   21.87  서울   서울 용산구  11030
# 3      서울특별시      성동구   면적 (㎢)   16.86  서울   서울 성동구  11040
# 4      서울특별시      광진구   면적 (㎢)   17.06  서울   서울 광진구  11050
# ..       ...      ...      ...     ...  ..      ...    ...
# 224     경상남도      함양군   면적 (㎢)  725.50  경남   경남 함양군  38380
# 225     경상남도      거창군   면적 (㎢)  803.38  경남   경남 거창군  38390
# 226     경상남도      합천군   면적 (㎢)  983.04  경남   경남 합천군  38400
# 227  제주특별자치도      제주시   면적 (㎢)  978.70  제주   제주 제주시  39010
# 228  제주특별자치도     서귀포시   면적 (㎢)  871.50  제주  제주 서귀포시  39020
#
# [229 rows x 7 columns]

# %%
# 원인 1 시도는 시군구 코드 0으로 처리 결과 확인
df_area[df_area['시군구코드'] == 0]
# Out:
#     행정구역별(1) 행정구역별(2) 인구현황별(1)     2020  시도 행정구역시군구명  시군구코드
# 75       경기도      수원시   면적 (㎢)   121.09  경기   경기 수원시      0
# 76       경기도      성남시   면적 (㎢)   141.63  경기   경기 성남시      0
# 78       경기도      안양시   면적 (㎢)    58.47  경기   경기 안양시      0
# 83       경기도      안산시   면적 (㎢)   156.33  경기   경기 안산시      0
# 84       경기도      고양시   면적 (㎢)   268.10  경기   경기 고양시      0
# 93       경기도      용인시   면적 (㎢)   591.23  경기   경기 용인시      0
# 124     충청북도      청주시   면적 (㎢)   940.81  충북   충북 청주시      0
# 135     충청남도      천안시   면적 (㎢)   636.09  충남   충남 천안시      0
# 150     전라북도      전주시   면적 (㎢)   206.00  전북   전북 전주시      0
# 186     경상북도      포항시   면적 (㎢)  1130.08  경북   경북 포항시      0
# 209     경상남도      창원시   면적 (㎢)   748.06  경남   경남 창원시      0

# %%
df_area
# Out:
#     행정구역별(1) 행정구역별(2) 인구현황별(1)    2020  시도 행정구역시군구명  시군구코드
# 0      서울특별시      종로구   면적 (㎢)   23.91  서울   서울 종로구  11010
# 1      서울특별시       중구   면적 (㎢)    9.96  서울    서울 중구  11020
# 2      서울특별시      용산구   면적 (㎢)   21.87  서울   서울 용산구  11030
# 3      서울특별시      성동구   면적 (㎢)   16.86  서울   서울 성동구  11040
# 4      서울특별시      광진구   면적 (㎢)   17.06  서울   서울 광진구  11050
# ..       ...      ...      ...     ...  ..      ...    ...
# 224     경상남도      함양군   면적 (㎢)  725.50  경남   경남 함양군  38380
# 225     경상남도      거창군   면적 (㎢)  803.38  경남   경남 거창군  38390
# 226     경상남도      합천군   면적 (㎢)  983.04  경남   경남 합천군  38400
# 227  제주특별자치도      제주시   면적 (㎢)  978.70  제주   제주 제주시  39010
# 228  제주특별자치도     서귀포시   면적 (㎢)  871.50  제주  제주 서귀포시  39020
#
# [229 rows x 7 columns]

# %%
# 시군구코드별 소아 인구수
df_people_group
# Out:
#      시군구코드  소아인구수
# 0    11010    521
# 1    11020    416
# 2    11030    567
# 3    11040    552
# 4    11050    677
# ..     ...    ...
# 245  38380    182
# 246  38390    168
# 247  38400    179
# 248  39010   1208
# 249  39020    479
#
# [250 rows x 2 columns]

# %%
 df_area_copy = df_area.copy()

# %%
df_area_copy['소아인구수'] = 0
df_area_copy
# Out:
#     행정구역별(1) 행정구역별(2) 인구현황별(1)    2020  시도 행정구역시군구명  시군구코드  소아인구수
# 0      서울특별시      종로구   면적 (㎢)   23.91  서울   서울 종로구  11010      0
# 1      서울특별시       중구   면적 (㎢)    9.96  서울    서울 중구  11020      0
# 2      서울특별시      용산구   면적 (㎢)   21.87  서울   서울 용산구  11030      0
# 3      서울특별시      성동구   면적 (㎢)   16.86  서울   서울 성동구  11040      0
# 4      서울특별시      광진구   면적 (㎢)   17.06  서울   서울 광진구  11050      0
# ..       ...      ...      ...     ...  ..      ...    ...    ...
# 224     경상남도      함양군   면적 (㎢)  725.50  경남   경남 함양군  38380      0
# 225     경상남도      거창군   면적 (㎢)  803.38  경남   경남 거창군  38390      0
# 226     경상남도      합천군   면적 (㎢)  983.04  경남   경남 합천군  38400      0
# 227  제주특별자치도      제주시   면적 (㎢)  978.70  제주   제주 제주시  39010      0
# 228  제주특별자치도     서귀포시   면적 (㎢)  871.50  제주  제주 서귀포시  39020      0
#
# [229 rows x 8 columns]

# %%
for i in range(len(df_area_copy)):
    for j in range(len(df_people_group)):
        if df_area_copy['시군구코드'][i] == df_people_group['시군구코드'][j]:
            df_area_copy['소아인구수'][i] = df_people_group['소아인구수'][j]

# %%
df_area_copy
# Out:
#     행정구역별(1) 행정구역별(2) 인구현황별(1)    2020  시도 행정구역시군구명  시군구코드  소아인구수
# 0      서울특별시      종로구   면적 (㎢)   23.91  서울   서울 종로구  11010    521
# 1      서울특별시       중구   면적 (㎢)    9.96  서울    서울 중구  11020    416
# 2      서울특별시      용산구   면적 (㎢)   21.87  서울   서울 용산구  11030    567
# 3      서울특별시      성동구   면적 (㎢)   16.86  서울   서울 성동구  11040    552
# 4      서울특별시      광진구   면적 (㎢)   17.06  서울   서울 광진구  11050    677
# ..       ...      ...      ...     ...  ..      ...    ...    ...
# 224     경상남도      함양군   면적 (㎢)  725.50  경남   경남 함양군  38380    182
# 225     경상남도      거창군   면적 (㎢)  803.38  경남   경남 거창군  38390    168
# 226     경상남도      합천군   면적 (㎢)  983.04  경남   경남 합천군  38400    179
# 227  제주특별자치도      제주시   면적 (㎢)  978.70  제주   제주 제주시  39010   1208
# 228  제주특별자치도     서귀포시   면적 (㎢)  871.50  제주  제주 서귀포시  39020    479
#
# [229 rows x 8 columns]

# %%
temp = df_area_copy[df_area_copy['소아인구수'] == 0]
temp
# Out:
#     행정구역별(1) 행정구역별(2) 인구현황별(1)     2020  시도 행정구역시군구명  시군구코드  소아인구수
# 75       경기도      수원시   면적 (㎢)   121.09  경기   경기 수원시      0      0
# 76       경기도      성남시   면적 (㎢)   141.63  경기   경기 성남시      0      0
# 78       경기도      안양시   면적 (㎢)    58.47  경기   경기 안양시      0      0
# 83       경기도      안산시   면적 (㎢)   156.33  경기   경기 안산시      0      0
# 84       경기도      고양시   면적 (㎢)   268.10  경기   경기 고양시      0      0
# 93       경기도      용인시   면적 (㎢)   591.23  경기   경기 용인시      0      0
# 124     충청북도      청주시   면적 (㎢)   940.81  충북   충북 청주시      0      0
# 135     충청남도      천안시   면적 (㎢)   636.09  충남   충남 천안시      0      0
# 150     전라북도      전주시   면적 (㎢)   206.00  전북   전북 전주시      0      0
# 186     경상북도      포항시   면적 (㎢)  1130.08  경북   경북 포항시      0      0
# 209     경상남도      창원시   면적 (㎢)   748.06  경남   경남 창원시      0      0

# %%
name_list = temp['행정구역시군구명'].values

# %%
map_si_num
# Out:
# {'경기 수원시': {'경기 장안구': 31011, '경기 권선구': 31012, '경기 팔달구': 31013},
#  '경기 성남시': {'경기 중원구': 31022, '경기 분당구': 31023},
#  '경기 안양시': {'경기 만안구': 31041, '경기 동안구': 31042},
#  '경기 안산시': {'경기 상록구': 31091, '경기 단원구': 31092},
#  '경기 고양시': {'경기 일산동구': 31103, '경기 일산서구': 31104},
#  '경기 용인시': {'경기 처인구': 31191, '경기 기흥구': 31192, '경기 수지구': 31193},
#  '충북 청주시': {'충북 상당구': 33041,
#   '충북 서원구': 33042,
#   '충북 흥덕구': 33043,
#   '충북 청원구': 33044},
#  '충남 천안시': {'충남 동남구': 34011, '충남 서북구': 34012},
#  '전북 전주시': {'전북 완산구': 35011, '전북 덕진구': 35012},
#  '경북 포항시': {'경북 포항시 남구': 37011, '경북 포항시 북구': 37012},
#  '경남 창원시': {'경남 창원시 의창구': 38111,
#   '경남 창원시 성산구': 38112,
#   '경남 창원시 마산합포구': 38113,
#   '경남 창원시 마산회원구': 38114,
#   '경남 창원시 진해구': 38115}}

# %%
map_si_num['경기 수원시']
# Out:
# {'경기 장안구': 31011, '경기 권선구': 31012, '경기 팔달구': 31013}

# %%
name_list2 = list(map_si_num['경기 수원시'].keys())

# %%
map_si_num['경기 수원시'][list(map_si_num['경기 수원시'].keys())[0]]
# Out:
# 31011

# %%
temp_dict = {}
for name in name_list:
    name_list2 = list(map_si_num[name].keys())
    res_dict[name] = temp_dict
    for name2 in name_list2:
        for j in range(len(df_people_group)):
            if map_si_num[name][name2] == df_people_group['시군구코드'][j]:
                temp_dict[name2] = df_people_group['소아인구수'][j]

# %%
temp_dict
# Out:
# {'경기 장안구': 737,
#  '경기 권선구': 916,
#  '경기 팔달구': 460,
#  '경기 중원구': 637,
#  '경기 분당구': 2093,
#  '경기 만안구': 638,
#  '경기 동안구': 994,
#  '경기 상록구': 853,
#  '경기 단원구': 981,
#  '경기 일산동구': 925,
#  '경기 일산서구': 1041,
#  '경기 처인구': 695,
#  '경기 기흥구': 1408,
#  '경기 수지구': 1412,
#  '충북 상당구': 662,
#  '충북 서원구': 607,
#  '충북 흥덕구': 804,
#  '충북 청원구': 836,
#  '충남 동남구': 758,
#  '충남 서북구': 1216,
#  '전북 완산구': 919,
#  '전북 덕진구': 1054,
#  '경북 포항시 남구': 670,
#  '경북 포항시 북구': 739,
#  '경남 창원시 의창구': 894,
#  '경남 창원시 성산구': 782,
#  '경남 창원시 마산합포구': 572,
#  '경남 창원시 마산회원구': 631,
#  '경남 창원시 진해구': 826}

# %%
df_people_group[df_people_group['시군구코드'] == 31013]
# Out:
#     시군구코드  소아인구수
# 77  31013    460

# %% [markdown]
# # 통합데이터 기준 다시 전처리(여기서 부터 돌리면 됨)

# %%
path = '/content/drive/MyDrive/mulcam_bigdata/2024통계데이터공모전/기획_데이터수집/성원님/Data/마지막주 데이터/통합데이터기준_중분류_시도명_시군구명.csv'

통합데이터 =  pd.read_csv(path, encoding='cp949')

# %%
df = 통합데이터.copy()

# %%
df
# Out:
#        중분류 행정구역시도명 행정구역시군구명  아동인구수  병원개수  인구 천명당 병원수
# 0    31050     경기도      부천시   1801   1.0    0.000555
# 1    31240     경기도      화성시   1785   2.0    0.001120
# 2    31023     경기도      분당구   1736   0.0    0.000000
# 3    31130     경기도     남양주시   1472   1.0    0.000679
# 4    11230   서울특별시      강남구   1405   2.0    0.001423
# ..     ...     ...      ...    ...   ...         ...
# 245  32410     강원도      양양군     82   0.0    0.000000
# 246  37330    경상북도      청송군     72   0.0    0.000000
# 247  37340    경상북도      영양군     67   0.0    0.000000
# 248  37310    경상북도      군위군     62   0.0    0.000000
# 249  37430    경상북도      울릉군     42   0.0    0.000000
#
# [250 rows x 6 columns]

# %%
len(df)
# Out:
# 250

# %%
df_area_copy.columns
# Out:
# Index(['행정구역별(1)', '행정구역별(2)', '인구현황별(1)', '2020', '시도', '행정구역시군구명', '시군구코드',
#        '소아인구수'],
#       dtype='object')

# %%
# 면적 데이터를 담을 새로운 열 생성
df['면적'] = 0

# %%
for i in range(len(df_area_copy)):
    for j in range(len(df)):
        if df_area_copy['시군구코드'][i] == df['중분류'][j]:
            df['면적'][j] = df_area_copy['2020'][i]

# %%
df
# Out:
#        중분류 행정구역시도명 행정구역시군구명  아동인구수  병원개수  인구 천명당 병원수      면적
# 0    31050     경기도      부천시   1801   1.0    0.000555   53.45
# 1    31240     경기도      화성시   1785   2.0    0.001120  698.18
# 2    31023     경기도      분당구   1736   0.0    0.000000    0.00
# 3    31130     경기도     남양주시   1472   1.0    0.000679  458.14
# 4    11230   서울특별시      강남구   1405   2.0    0.001423   39.50
# ..     ...     ...      ...    ...   ...         ...     ...
# 245  32410     강원도      양양군     82   0.0    0.000000  630.01
# 246  37330    경상북도      청송군     72   0.0    0.000000  846.12
# 247  37340    경상북도      영양군     67   0.0    0.000000  815.75
# 248  37310    경상북도      군위군     62   0.0    0.000000  614.32
# 249  37430    경상북도      울릉군     42   0.0    0.000000   72.94
#
# [250 rows x 7 columns]

# %%
# 잘 담겼는지 확인
# 부천시 시군구코드 : 31050
df_area_copy['2020'][df_area_copy['시군구코드'] == 31050]
# Out:
# 79    53.45
# Name: 2020, dtype: float64

# %%
# 면적데이터의 시도 기준과 맞지 않은 32개 안 담겼다 >> 예상한 결과
# 32개의 구단위 면적 데이터 찾아서 넣어주기
len(df[df['면적'] == 0])
# Out:
# 32

# %%
df[df['면적'] == 0]
# Out:
#        중분류 행정구역시도명 행정구역시군구명  아동인구수  병원개수  인구 천명당 병원수   면적
# 2    31023     경기도      분당구   1736   0.0         0.0  0.0
# 6    31192     경기도      기흥구   1152   0.0         0.0  0.0
# 7    31193     경기도      수지구   1152   0.0         0.0  0.0
# 27   31014     경기도      영통구    925   0.0         0.0  0.0
# 29   34012    충청남도      서북구    920   0.0         0.0  0.0
# 33   31101     경기도      덕양구    883   0.0         0.0  0.0
# 34   31104     경기도     일산서구    865   0.0         0.0  0.0
# 37   35012    전라북도      덕진구    855   0.0         0.0  0.0
# 41   31042     경기도      동안구    814   0.0         0.0  0.0
# 44   31092     경기도      단원구    807   0.0         0.0  0.0
# 47   31103     경기도     일산동구    772   0.0         0.0  0.0
# 49   35011    전라북도      완산구    761   0.0         0.0  0.0
# 56   31012     경기도      권선구    718   0.0         0.0  0.0
# 57   38111    경상남도      의창구    716   0.0         0.0  0.0
# 58   31091     경기도      상록구    705   0.0         0.0  0.0
# ...

# %%
df[df['면적'] == 0]['행정구역시군구명'].values
# Out:
# array(['분당구', '기흥구', '수지구', '영통구', '서북구', '덕양구', '일산서구', '덕진구', '동안구',
#        '단원구', '일산동구', '완산구', '권선구', '의창구', '상록구', '진해구', '성산구', '청원구',
#        '흥덕구', '동남구', '장안구', '수정구', '북구', '처인구', '남구', '상당구', '마산회원구',
#        '서원구', '중원구', '만안구', '마산합포구', '팔달구'], dtype=object)

# %%
# 네이버 여행정보 기준 자료 수집
# 위키백과 기준 자료 수집
map_gu = {'분당구' : 69.49, '기흥구' : 81.6, '수지구' : 42.1, '영통구' : 27.68, '서북구' : 197.73, '덕양구' : 165.44, '일산서구' : 42.77, '덕진구' : 131.143, '동안구' : 21.93,
       '단원구' : 91.51, '일산동구' : 59.1, '완산구' : 92.59, '권선구' : 47.17, '의창구' : 204.89, '상록구' : 57.99, '진해구' : 123.67, '성산구' : 89.06, '청원구' : 214.99,
       '흥덕구' : 198.27, '동남구' : 438.56, '장안구' : 33.34, '수정구' : 45.46, '북구' : 734.72, '처인구' : 467.6, '남구' : 393.02, '상당구' : 404.44, '마산회원구' : 90.58,
       '서원구' : 122.59, '중원구' : 26.38, '만안구' : 36.60, '마산합포구' : 19.51, '팔달구' : 12.86}

# %%
# 자료 수집시 참고용
map_si_num
# Out:
# {'경기 수원시': {'경기 장안구': 31011, '경기 권선구': 31012, '경기 팔달구': 31013},
#  '경기 성남시': {'경기 중원구': 31022, '경기 분당구': 31023},
#  '경기 안양시': {'경기 만안구': 31041, '경기 동안구': 31042},
#  '경기 안산시': {'경기 상록구': 31091, '경기 단원구': 31092},
#  '경기 고양시': {'경기 일산동구': 31103, '경기 일산서구': 31104},
#  '경기 용인시': {'경기 처인구': 31191, '경기 기흥구': 31192, '경기 수지구': 31193},
#  '충북 청주시': {'충북 상당구': 33041,
#   '충북 서원구': 33042,
#   '충북 흥덕구': 33043,
#   '충북 청원구': 33044},
#  '충남 천안시': {'충남 동남구': 34011, '충남 서북구': 34012},
#  '전북 전주시': {'전북 완산구': 35011, '전북 덕진구': 35012},
#  '경북 포항시': {'경북 포항시 남구': 37011, '경북 포항시 북구': 37012},
#  '경남 창원시': {'경남 창원시 의창구': 38111,
#   '경남 창원시 성산구': 38112,
#   '경남 창원시 마산합포구': 38113,
#   '경남 창원시 마산회원구': 38114,
#   '경남 창원시 진해구': 38115}}

# %% [markdown]
# 수집한 구단위 면적 데이터 할당하기

# %%
map_gu.keys()
# Out:
# dict_keys(['분당구', '기흥구', '수지구', '영통구', '서북구', '덕양구', '일산서구', '덕진구', '동안구', '단원구', '일산동구', '완산구', '권선구', '의창구', '상록구', '진해구', '성산구', '청원구', '흥덕구', '동남구', '장안구', '수정구', '북구', '처인구', '남구', '상당구', '마산회원구', '서원구', '중원구', '만안구', '마산합포구', '팔달구'])

# %%
len(map_gu.keys())
# Out:
# 32

# %%
for key in map_gu.keys():
    for j in range(len(df)):
        if key == df['행정구역시군구명'][j]:
            df['면적'][j] = map_gu[key]

# %%
# 잘 들어갔는지 확인
df[df['행정구역시군구명'] == '팔달구']
# Out:
#        중분류 행정구역시도명 행정구역시군구명  아동인구수  병원개수  인구 천명당 병원수     면적
# 140  31013     경기도      팔달구    379   0.0         0.0  12.86

# %%
# 잘들어갔다
df[df['면적'] == 0]
# Out:
# Empty DataFrame
# Columns: [중분류, 행정구역시도명, 행정구역시군구명, 아동인구수, 병원개수, 인구 천명당 병원수, 면적]
# Index: []

# %% [markdown]
# # 코랩에서 작업 디렉토리 확인하고 변경하는 코드

# %%
import os

# 현재 작업 디렉토리 출력
current_directory = os.getcwd()
print("현재 작업 디렉토리:", current_directory)
# Out:
# 현재 작업 디렉토리: /content

# %%
# 작업 디렉토리 변경
os.chdir('/content')

# 변경된 작업 디렉토리 출력
print("변경된 작업 디렉토리:", os.getcwd())
# Out:
# 변경된 작업 디렉토리: /content

# %%
# 결과물 저장
# df.to_csv('./drive/MyDrive/mulcam_bigdata/2024통계데이터공모전/기획_데이터수집/성원님/temp/통합데이터기준_중분류_시도명_시군구명_면적.csv',index=False)

# %%
path = '/content/drive/MyDrive/mulcam_bigdata/2024통계데이터공모전/기획_데이터수집/성원님/temp/통합데이터기준_중분류_시도명_시군구명_면적.csv'
pd.read_csv(path)
# Out:
#        중분류 행정구역시도명 행정구역시군구명  아동인구수  병원개수  인구 천명당 병원수      면적
# 0    31050     경기도      부천시   1801   1.0    0.000555   53.45
# 1    31240     경기도      화성시   1785   2.0    0.001120  698.18
# 2    31023     경기도      분당구   1736   0.0    0.000000   69.49
# 3    31130     경기도     남양주시   1472   1.0    0.000679  458.14
# 4    11230   서울특별시      강남구   1405   2.0    0.001423   39.50
# ..     ...     ...      ...    ...   ...         ...     ...
# 245  32410     강원도      양양군     82   0.0    0.000000  630.01
# 246  37330    경상북도      청송군     72   0.0    0.000000  846.12
# 247  37340    경상북도      영양군     67   0.0    0.000000  815.75
# 248  37310    경상북도      군위군     62   0.0    0.000000  614.32
# 249  37430    경상북도      울릉군     42   0.0    0.000000   72.94
#
# [250 rows x 7 columns]

# %%
df['행정구역시도명'].value_counts()
# Out:
# 행정구역시도명
# 경기도        42
# 서울특별시      25
# 경상북도       24
# 경상남도       22
# 전라남도       22
# 강원도        18
# 부산광역시      16
# 충청남도       16
# 전라북도       15
# 충청북도       14
# 인천광역시      10
# 대구광역시       8
# 광주광역시       5
# 대전광역시       5
# 울산광역시       5
# 제주특별자치도     2
# 세종특별자치시     1
# Name: count, dtype: int64

# %%
df[df['행정구역시도명'] == '제주특별자치도']
# Out:
#        중분류  행정구역시도명 행정구역시군구명  아동인구수  병원개수  인구 천명당 병원수     면적
# 24   39010  제주특별자치도      제주시    949   2.0    0.002107  978.7
# 138  39020  제주특별자치도     서귀포시    383   1.0    0.002611  871.5

# %%
df[df['행정구역시도명'] == '세종특별자치시']
# Out:
#       중분류  행정구역시도명 행정구역시군구명  아동인구수  병원개수  인구 천명당 병원수     면적
# 23  29010  세종특별자치시  세종특별자치시    963   0.0         0.0  465.0
